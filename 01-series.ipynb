# %%
import numpy as np
import pandas as pd

# %%
labels = ['a', 'b', 'c']
myList = [10, 20, 30]
arr = np.array([10, 20, 30])

# %%
pd.Series(myList)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(myList, index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64
